# %%
from pathlib import Path
import csv

menu_data = Path("../PyRamen/menu_data.csv")
sales_data = Path("../PyRamen/sales_data.csv")

menu_items = []
sales_info = []

report = {}

with open(menu_data, 'r') as menu:
    
    menu_reader = csv.reader(menu, delimiter=',')
    header = next(menu_reader)
    
    for row in menu_reader:
        if row[1] == "entree":
            menu_items.append([row[0],int(row[3]),int(row[4])])
        
with open(sales_data, 'r') as sales:
    
    sales_reader = csv.reader(sales, delimiter=',')
    header = next(sales_reader)
    
    for row in sales_reader:
        sales_info.append([row[4],int(row[3])])
        
for row in sales_info:
    print(row)
# Out:
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['tori paitan ramen', 3]
# ['tori paitan ramen', 3]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['truffle butter ramen', 2]
# ['truffle butter ramen', 2]
# ['tonkotsu ramen', 2]
# ['tonkotsu ramen', 2]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['tori paitan ramen', 2]
# ['tori paitan ramen', 2]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['tonkotsu ramen', 4]
# ['tonkotsu ramen', 4]
# ['miso crab ramen', 4]
# ['miso crab ramen', 4]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['nagomi shoyu', 3]
# ['nagomi shoyu', 3]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['nagomi shoyu', 2]
# ['nagomi shoyu', 2]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['soft-shell miso crab ramen', 2]
# ['soft-shell miso crab ramen', 2]
# ['spicy miso ramen', 4]
# ['spicy miso ramen', 4]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['burnt garlic tonkotsu ramen', 3]
# ['burnt garlic tonkotsu ramen', 3]
# ['miso crab ramen', 4]
# ['miso crab ramen', 4]
# ['truffle butter ramen', 3]
# ['truffle butter ramen', 3]
# ['vegetarian spicy miso', 3]
# ['vegetarian spicy miso', 3]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['truffle butter ramen', 3]
# ['truffle butter ramen', 3]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['vegetarian spicy miso', 2]
# ['vegetarian spicy miso', 2]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 4]
# ['nagomi shoyu', 4]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['soft-shell miso crab ramen', 2]
# ['soft-shell miso crab ramen', 2]
# ['shio ramen', 2]
# ['shio ramen', 2]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['tori paitan ramen', 3]
# ['tori paitan ramen', 3]
# ['miso crab ramen', 2]
# ['miso crab ramen', 2]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['spicy miso ramen', 3]
# ['spicy miso ramen', 3]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['soft-shell miso crab ramen', 2]
# ['soft-shell miso crab ramen', 2]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['burnt garlic tonkotsu ramen', 4]
# ['burnt garlic tonkotsu ramen', 4]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 2]
# ['vegetarian curry + king trumpet mushroom ramen', 2]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['miso crab ramen', 2]
# ['miso crab ramen', 2]
# ['burnt garlic tonkotsu ramen', 4]
# ['burnt garlic tonkotsu ramen', 4]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['truffle butter ramen', 4]
# ['truffle butter ramen', 4]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['tonkotsu ramen', 3]
# ['tonkotsu ramen', 3]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['tori paitan ramen', 2]
# ['tori paitan ramen', 2]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['tonkotsu ramen', 3]
# ['tonkotsu ramen', 3]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['tori paitan ramen', 2]
# ['tori paitan ramen', 2]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['miso crab ramen', 2]
# ['miso crab ramen', 2]
# ['tori paitan ramen', 2]
# ['tori paitan ramen', 2]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 2]
# ['truffle butter ramen', 2]
# ['tonkotsu ramen', 3]
# ['tonkotsu ramen', 3]
# ['burnt garlic tonkotsu ramen', 4]
# ['burnt garlic tonkotsu ramen', 4]
# ['tonkotsu ramen', 2]
# ['tonkotsu ramen', 2]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['truffle butter ramen', 2]
# ['truffle butter ramen', 2]
# ['shio ramen', 4]
# ['shio ramen', 4]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['burnt garlic tonkotsu ramen', 2]
# ['burnt garlic tonkotsu ramen', 2]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['tori paitan ramen', 2]
# ['tori paitan ramen', 2]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['burnt garlic tonkotsu ramen', 4]
# ['burnt garlic tonkotsu ramen', 4]
# ['spicy miso ramen', 4]
# ['spicy miso ramen', 4]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['burnt garlic tonkotsu ramen', 2]
# ['burnt garlic tonkotsu ramen', 2]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 2]
# ['tori paitan ramen', 2]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['spicy miso ramen', 4]
# ['spicy miso ramen', 4]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['nagomi shoyu', 3]
# ['nagomi shoyu', 3]
# ['shio ramen', 3]
# ['shio ramen', 3]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['spicy miso ramen', 4]
# ['spicy miso ramen', 4]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['shio ramen', 4]
# ['shio ramen', 4]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 3]
# ['vegetarian curry + king trumpet mushroom ramen', 3]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['spicy miso ramen', 2]
# ['spicy miso ramen', 2]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['soft-shell miso crab ramen', 4]
# ['soft-shell miso crab ramen', 4]
# ['vegetarian spicy miso', 2]
# ['vegetarian spicy miso', 2]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['soft-shell miso crab ramen', 2]
# ['soft-shell miso crab ramen', 2]
# ['tori paitan ramen', 4]
# ['tori paitan ramen', 4]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['spicy miso ramen', 4]
# ['spicy miso ramen', 4]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['tonkotsu ramen', 3]
# ['tonkotsu ramen', 3]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tonkotsu ramen', 2]
# ['tonkotsu ramen', 2]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['miso crab ramen', 2]
# ['miso crab ramen', 2]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['vegetarian spicy miso', 3]
# ['vegetarian spicy miso', 3]
# ['shio ramen', 2]
# ['shio ramen', 2]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 2]
# ['burnt garlic tonkotsu ramen', 2]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['burnt garlic tonkotsu ramen', 3]
# ['burnt garlic tonkotsu ramen', 3]
# ['spicy miso ramen', 2]
# ['spicy miso ramen', 2]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['truffle butter ramen', 2]
# ['truffle butter ramen', 2]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['soft-shell miso crab ramen', 4]
# ['soft-shell miso crab ramen', 4]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['truffle butter ramen', 2]
# ['truffle butter ramen', 2]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['truffle butter ramen', 2]
# ['truffle butter ramen', 2]
# ['miso crab ramen', 2]
# ['miso crab ramen', 2]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['vegetarian spicy miso', 3]
# ['vegetarian spicy miso', 3]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['shio ramen', 3]
# ['shio ramen', 3]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['nagomi shoyu', 3]
# ['nagomi shoyu', 3]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 4]
# ['vegetarian curry + king trumpet mushroom ramen', 4]
# ['tori paitan ramen', 3]
# ['tori paitan ramen', 3]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['tonkotsu ramen', 3]
# ['tonkotsu ramen', 3]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 3]
# ['truffle butter ramen', 3]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['shio ramen', 2]
# ['shio ramen', 2]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['burnt garlic tonkotsu ramen', 2]
# ['burnt garlic tonkotsu ramen', 2]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 2]
# ['vegetarian curry + king trumpet mushroom ramen', 2]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['vegetarian spicy miso', 2]
# ['vegetarian spicy miso', 2]
# ['shio ramen', 4]
# ['shio ramen', 4]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['spicy miso ramen', 4]
# ['spicy miso ramen', 4]
# ['soft-shell miso crab ramen', 2]
# ['soft-shell miso crab ramen', 2]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['truffle butter ramen', 2]
# ['truffle butter ramen', 2]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['spicy miso ramen', 3]
# ['spicy miso ramen', 3]
# ['tori paitan ramen', 4]
# ['tori paitan ramen', 4]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['vegetarian spicy miso', 2]
# ['vegetarian spicy miso', 2]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 4]
# ['spicy miso ramen', 4]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['burnt garlic tonkotsu ramen', 4]
# ['burnt garlic tonkotsu ramen', 4]
# ['truffle butter ramen', 2]
# ['truffle butter ramen', 2]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['miso crab ramen', 3]
# ['miso crab ramen', 3]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['shio ramen', 4]
# ['shio ramen', 4]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['nagomi shoyu', 3]
# ['nagomi shoyu', 3]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 4]
# ['soft-shell miso crab ramen', 4]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['tori paitan ramen', 2]
# ['tori paitan ramen', 2]
# ['tori paitan ramen', 4]
# ['tori paitan ramen', 4]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['shio ramen', 2]
# ['shio ramen', 2]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['spicy miso ramen', 4]
# ['spicy miso ramen', 4]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 3]
# ['vegetarian curry + king trumpet mushroom ramen', 3]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['nagomi shoyu', 2]
# ['nagomi shoyu', 2]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['truffle butter ramen', 3]
# ['truffle butter ramen', 3]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['vegetarian spicy miso', 2]
# ['vegetarian spicy miso', 2]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['vegetarian spicy miso', 2]
# ['vegetarian spicy miso', 2]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['nagomi shoyu', 2]
# ['nagomi shoyu', 2]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['miso crab ramen', 4]
# ['miso crab ramen', 4]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 3]
# ['burnt garlic tonkotsu ramen', 3]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['spicy miso ramen', 2]
# ['spicy miso ramen', 2]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['miso crab ramen', 4]
# ['miso crab ramen', 4]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['vegetarian spicy miso', 3]
# ['vegetarian spicy miso', 3]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['spicy miso ramen', 2]
# ['spicy miso ramen', 2]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['shio ramen', 2]
# ['shio ramen', 2]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['nagomi shoyu', 2]
# ['nagomi shoyu', 2]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['truffle butter ramen', 3]
# ['truffle butter ramen', 3]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['soft-shell miso crab ramen', 4]
# ['soft-shell miso crab ramen', 4]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['nagomi shoyu', 3]
# ['nagomi shoyu', 3]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['vegetarian spicy miso', 2]
# ['vegetarian spicy miso', 2]
# ['miso crab ramen', 3]
# ['miso crab ramen', 3]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['miso crab ramen', 2]
# ['miso crab ramen', 2]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['miso crab ramen', 2]
# ['miso crab ramen', 2]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['burnt garlic tonkotsu ramen', 2]
# ['burnt garlic tonkotsu ramen', 2]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['truffle butter ramen', 4]
# ['truffle butter ramen', 4]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['vegetarian spicy miso', 3]
# ['vegetarian spicy miso', 3]
# ['miso crab ramen', 3]
# ['miso crab ramen', 3]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['vegetarian spicy miso', 2]
# ['vegetarian spicy miso', 2]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 2]
# ['vegetarian curry + king trumpet mushroom ramen', 2]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['nagomi shoyu', 4]
# ['nagomi shoyu', 4]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['vegetarian spicy miso', 2]
# ['vegetarian spicy miso', 2]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['miso crab ramen', 2]
# ['miso crab ramen', 2]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['shio ramen', 2]
# ['shio ramen', 2]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 2]
# ['spicy miso ramen', 2]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['shio ramen', 4]
# ['shio ramen', 4]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['miso crab ramen', 4]
# ['miso crab ramen', 4]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['soft-shell miso crab ramen', 3]
# ['soft-shell miso crab ramen', 3]
# ['miso crab ramen', 3]
# ['miso crab ramen', 3]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['soft-shell miso crab ramen', 4]
# ['soft-shell miso crab ramen', 4]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['shio ramen', 2]
# ['shio ramen', 2]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['nagomi shoyu', 3]
# ['nagomi shoyu', 3]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tonkotsu ramen', 2]
# ['tonkotsu ramen', 2]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['shio ramen', 2]
# ['shio ramen', 2]
# ['soft-shell miso crab ramen', 2]
# ['soft-shell miso crab ramen', 2]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['burnt garlic tonkotsu ramen', 2]
# ['burnt garlic tonkotsu ramen', 2]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['soft-shell miso crab ramen', 4]
# ['soft-shell miso crab ramen', 4]
# ['vegetarian curry + king trumpet mushroom ramen', 4]
# ['vegetarian curry + king trumpet mushroom ramen', 4]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 3]
# ['tonkotsu ramen', 3]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tori paitan ramen', 2]
# ['tori paitan ramen', 2]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['tori paitan ramen', 4]
# ['tori paitan ramen', 4]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['burnt garlic tonkotsu ramen', 3]
# ['burnt garlic tonkotsu ramen', 3]
# ['burnt garlic tonkotsu ramen', 3]
# ['burnt garlic tonkotsu ramen', 3]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['shio ramen', 4]
# ['shio ramen', 4]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['tori paitan ramen', 2]
# ['tori paitan ramen', 2]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['vegetarian spicy miso', 4]
# ['vegetarian spicy miso', 4]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['shio ramen', 3]
# ['shio ramen', 3]
# ['tori paitan ramen', 2]
# ['tori paitan ramen', 2]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['nagomi shoyu', 4]
# ['nagomi shoyu', 4]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['burnt garlic tonkotsu ramen', 2]
# ['burnt garlic tonkotsu ramen', 2]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian spicy miso', 4]
# ['vegetarian spicy miso', 4]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['nagomi shoyu', 2]
# ['nagomi shoyu', 2]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['burnt garlic tonkotsu ramen', 3]
# ['burnt garlic tonkotsu ramen', 3]
# ['tonkotsu ramen', 2]
# ['tonkotsu ramen', 2]
# ['nagomi shoyu', 3]
# ['nagomi shoyu', 3]
# ['nagomi shoyu', 2]
# ['nagomi shoyu', 2]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 3]
# ['vegetarian curry + king trumpet mushroom ramen', 3]
# ['vegetarian curry + king trumpet mushroom ramen', 2]
# ['vegetarian curry + king trumpet mushroom ramen', 2]
# ['shio ramen', 4]
# ['shio ramen', 4]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['vegetarian spicy miso', 4]
# ['vegetarian spicy miso', 4]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['spicy miso ramen', 3]
# ['spicy miso ramen', 3]
# ['truffle butter ramen', 2]
# ['truffle butter ramen', 2]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 4]
# ['spicy miso ramen', 4]
# ['vegetarian spicy miso', 2]
# ['vegetarian spicy miso', 2]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['spicy miso ramen', 2]
# ['spicy miso ramen', 2]
# ['vegetarian spicy miso', 4]
# ['vegetarian spicy miso', 4]
# ['tori paitan ramen', 3]
# ['tori paitan ramen', 3]
# ['shio ramen', 2]
# ['shio ramen', 2]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['nagomi shoyu', 4]
# ['nagomi shoyu', 4]
# ['truffle butter ramen', 1]
# ...
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 2]
# ['vegetarian curry + king trumpet mushroom ramen', 2]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['soft-shell miso crab ramen', 2]
# ['soft-shell miso crab ramen', 2]
# ['tonkotsu ramen', 2]
# ['tonkotsu ramen', 2]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 2]
# ['tori paitan ramen', 2]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['spicy miso ramen', 4]
# ['spicy miso ramen', 4]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['soft-shell miso crab ramen', 2]
# ['soft-shell miso crab ramen', 2]
# ['nagomi shoyu', 3]
# ['nagomi shoyu', 3]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['burnt garlic tonkotsu ramen', 2]
# ['burnt garlic tonkotsu ramen', 2]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['shio ramen', 2]
# ['shio ramen', 2]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['truffle butter ramen', 3]
# ['truffle butter ramen', 3]
# ['tonkotsu ramen', 3]
# ['tonkotsu ramen', 3]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['soft-shell miso crab ramen', 2]
# ['soft-shell miso crab ramen', 2]
# ['soft-shell miso crab ramen', 2]
# ['soft-shell miso crab ramen', 2]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['nagomi shoyu', 4]
# ['nagomi shoyu', 4]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tonkotsu ramen', 4]
# ['tonkotsu ramen', 4]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 2]
# ['tori paitan ramen', 2]
# ['tonkotsu ramen', 2]
# ['tonkotsu ramen', 2]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['shio ramen', 2]
# ['shio ramen', 2]
# ['vegetarian curry + king trumpet mushroom ramen', 2]
# ['vegetarian curry + king trumpet mushroom ramen', 2]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['truffle butter ramen', 3]
# ['truffle butter ramen', 3]
# ['spicy miso ramen', 2]
# ['spicy miso ramen', 2]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['soft-shell miso crab ramen', 4]
# ['soft-shell miso crab ramen', 4]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['soft-shell miso crab ramen', 2]
# ['soft-shell miso crab ramen', 2]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 2]
# ['burnt garlic tonkotsu ramen', 2]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['tonkotsu ramen', 2]
# ['tonkotsu ramen', 2]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['spicy miso ramen', 3]
# ['spicy miso ramen', 3]
# ['spicy miso ramen', 4]
# ['spicy miso ramen', 4]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['nagomi shoyu', 3]
# ['nagomi shoyu', 3]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['spicy miso ramen', 4]
# ['spicy miso ramen', 4]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['tori paitan ramen', 2]
# ['tori paitan ramen', 2]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['tori paitan ramen', 2]
# ['tori paitan ramen', 2]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['tori paitan ramen', 2]
# ['tori paitan ramen', 2]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 2]
# ['vegetarian curry + king trumpet mushroom ramen', 2]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['shio ramen', 2]
# ['shio ramen', 2]
# ['vegetarian curry + king trumpet mushroom ramen', 4]
# ['vegetarian curry + king trumpet mushroom ramen', 4]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['truffle butter ramen', 2]
# ['truffle butter ramen', 2]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['burnt garlic tonkotsu ramen', 2]
# ['burnt garlic tonkotsu ramen', 2]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 4]
# ['soft-shell miso crab ramen', 4]
# ['burnt garlic tonkotsu ramen', 2]
# ['burnt garlic tonkotsu ramen', 2]
# ['miso crab ramen', 4]
# ['miso crab ramen', 4]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 4]
# ['vegetarian curry + king trumpet mushroom ramen', 4]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 2]
# ['shio ramen', 2]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['spicy miso ramen', 4]
# ['spicy miso ramen', 4]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 2]
# ['tori paitan ramen', 2]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['truffle butter ramen', 2]
# ['truffle butter ramen', 2]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['vegetarian spicy miso', 3]
# ['vegetarian spicy miso', 3]
# ['truffle butter ramen', 2]
# ['truffle butter ramen', 2]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 1]
# ['soft-shell miso crab ramen', 2]
# ['soft-shell miso crab ramen', 2]
# ['miso crab ramen', 1]
# ['miso crab ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 3]
# ['vegetarian curry + king trumpet mushroom ramen', 3]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['miso crab ramen', 4]
# ['miso crab ramen', 4]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 2]
# ['nagomi shoyu', 2]
# ['vegetarian curry + king trumpet mushroom ramen', 2]
# ['vegetarian curry + king trumpet mushroom ramen', 2]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 3]
# ['shio ramen', 3]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 4]
# ['vegetarian curry + king trumpet mushroom ramen', 4]
# ['tori paitan ramen', 1]
# ['tori paitan ramen', 1]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['spicy miso ramen', 1]
# ['spicy miso ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 2]
# ['vegetarian curry + king trumpet mushroom ramen', 2]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['soft-shell miso crab ramen', 2]
# ['soft-shell miso crab ramen', 2]
# ['nagomi shoyu', 1]
# ['nagomi shoyu', 1]
# ['vegetarian spicy miso', 1]
# ['vegetarian spicy miso', 1]
# ['burnt garlic tonkotsu ramen', 3]
# ['burnt garlic tonkotsu ramen', 3]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['shio ramen', 1]
# ['shio ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['burnt garlic tonkotsu ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['truffle butter ramen', 1]
# ['truffle butter ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['vegetarian curry + king trumpet mushroom ramen', 1]
# ['tonkotsu ramen', 1]
# ['tonkotsu ramen', 1]
